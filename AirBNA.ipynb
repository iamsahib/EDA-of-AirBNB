# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **IMPORTING THE DATA**

# %%
df = pd.read_csv(r"D:\Data for projects\AirBnB\datasets.csv",encoding_errors = 'ignore')
df
# Out:
#                  id                                               name  \
# 0      1.312228e+06         Rental unit in Brooklyn · ★5.0 · 1 bedroom
# 1      4.527754e+07  Rental unit in New York · ★4.67 · 2 bedrooms ·...
# 2      9.710000e+17  Rental unit in New York · ★4.17 · 1 bedroom · ...
# 3      3.857863e+06  Rental unit in New York · ★4.64 · 1 bedroom · ...
# 4      4.089661e+07  Condo in New York · ★4.91 · Studio · 1 bed · 1...
# ...             ...                                                ...
# 20765  2.473690e+07  Rental unit in New York · ★4.75 · 1 bedroom · ...
# 20766  2.835711e+06  Rental unit in New York · ★4.46 · 1 bedroom · ...
# 20767  5.182527e+07  Rental unit in New York · ★4.93 · 1 bedroom · ...
# 20768  7.830000e+17  Rental unit in New York · ★5.0 · 1 bedroom · 1...
# 20769  5.660000e+17  Rental unit in Queens · ★4.89 · 1 bedroom · 1 ...
#
#          host_id           host_name neighbourhood_group       neighbourhood  \
# ...

# %% [markdown]
# **EXPLORING THE DATA**

# %%
df.head()
# Out:
#              id                                               name    host_id  \
# 0  1.312228e+06         Rental unit in Brooklyn · ★5.0 · 1 bedroom    7130382
# 1  4.527754e+07  Rental unit in New York · ★4.67 · 2 bedrooms ·...   51501835
# 2  9.710000e+17  Rental unit in New York · ★4.17 · 1 bedroom · ...  528871354
# 3  3.857863e+06  Rental unit in New York · ★4.64 · 1 bedroom · ...   19902271
# 4  4.089661e+07  Condo in New York · ★4.91 · Studio · 1 bed · 1...   61391963
#
#             host_name neighbourhood_group       neighbourhood   latitude  \
# 0              Walter            Brooklyn        Clinton Hill  40.683710
# 1            Jeniffer           Manhattan      Hell's Kitchen  40.766610
# 2              Joshua           Manhattan             Chelsea  40.750764
# 3  John And Catherine           Manhattan  Washington Heights  40.835600
# 4      Stay With Vibe           Manhattan         Murray Hill  40.751120
#
# ...

# %%
df.tail()
# Out:
#                  id                                               name  \
# 20765  2.473690e+07  Rental unit in New York · ★4.75 · 1 bedroom · ...
# 20766  2.835711e+06  Rental unit in New York · ★4.46 · 1 bedroom · ...
# 20767  5.182527e+07  Rental unit in New York · ★4.93 · 1 bedroom · ...
# 20768  7.830000e+17  Rental unit in New York · ★5.0 · 1 bedroom · 1...
# 20769  5.660000e+17  Rental unit in Queens · ★4.89 · 1 bedroom · 1 ...
#
#          host_id host_name neighbourhood_group      neighbourhood   latitude  \
# 20765  186680487   Henry D           Manhattan    Lower East Side  40.711380
# 20766    3237504     Aspen           Manhattan  Greenwich Village  40.730580
# 20767  304317395      Jeff           Manhattan     Hell's Kitchen  40.757350
# 20768  163083101   Marissa           Manhattan          Chinatown  40.713750
# 20769   93827372   Glenroy              Queens           Rosedale  40.658874
#
# ...

# %%
df.describe()
# Out:
#                  id       host_id      latitude     longitude          price  \
# count  2.077000e+04  2.077000e+04  20763.000000  20763.000000   20736.000000
# mean   3.033858e+17  1.749049e+08     40.726821    -73.939179     187.714940
# std    3.901221e+17  1.725657e+08      0.060293      0.061403    1023.245124
# min    2.595000e+03  1.678000e+03     40.500314    -74.249840      10.000000
# 25%    2.707260e+07  2.041184e+07     40.684159    -73.980755      80.000000
# 50%    4.992852e+07  1.086990e+08     40.722890    -73.949597     125.000000
# 75%    7.220000e+17  3.143997e+08     40.763106    -73.917475     199.000000
# max    1.050000e+18  5.504035e+08     40.911147    -73.713650  100000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    20763.000000       20763.000000       20763.000000
# mean        28.558493          42.610605           1.257589
# std         33.532697          73.523401           1.904472
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20770 entries, 0 to 20769
# Data columns (total 22 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              20770 non-null  float64
#  1   name                            20770 non-null  object
#  2   host_id                         20770 non-null  int64
#  3   host_name                       20770 non-null  object
#  4   neighbourhood_group             20770 non-null  object
#  5   neighbourhood                   20763 non-null  object
#  6   latitude                        20763 non-null  float64
#  7   longitude                       20763 non-null  float64
#  8   room_type                       20763 non-null  object
#  9   price                           20736 non-null  float64
#  10  minimum_nights                  20763 non-null  float64
#  11  number_of_reviews               20763 non-null  float64
# ...

# %%
df.shape
# Out:
# (20770, 22)

# %% [markdown]
# **DATA CLEANING**

# %%
df.isnull().sum()
# Out:
# id                                 0
# name                               0
# host_id                            0
# host_name                          0
# neighbourhood_group                0
# neighbourhood                      7
# latitude                           7
# longitude                          7
# room_type                          7
# price                             34
# minimum_nights                     7
# number_of_reviews                  7
# last_review                        7
# reviews_per_month                  7
# calculated_host_listings_count     7
# availability_365                   7
# number_of_reviews_ltm              7
# license                            0
# rating                             0
# bedrooms                           0
# beds                               0
# baths                              0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# number_of_reviews_ltm             0
# license                           0
# rating                            0
# bedrooms                          0
# beds                              0
# baths                             0
# dtype: int64

# %%
df.shape
# Out:
# (20736, 22)

# %%
df.duplicated().sum()  #finding duplicate
# Out:
# 12

# %%
df[df.duplicated()] #these are the duplicate values are in our data
# Out:
#                  id                                               name  \
# 6      4.527754e+07  Rental unit in New York · ★4.67 · 2 bedrooms ·...
# 7      9.710000e+17  Rental unit in New York · ★4.17 · 1 bedroom · ...
# 8      3.857863e+06  Rental unit in New York · ★4.64 · 1 bedroom · ...
# 9      4.089661e+07  Condo in New York · ★4.91 · Studio · 1 bed · 1...
# 10     4.958498e+07  Rental unit in New York · ★5.0 · 1 bedroom · 1...
# 20736  7.990000e+17  Rental unit in New York · 2 bedrooms · 2 beds ...
# 20737  5.930000e+17  Rental unit in New York · ★4.79 · 2 bedrooms ·...
# 20738  9.230000e+17  Loft in New York · ★4.33 · 1 bedroom · 2 beds ...
# 20739  1.336161e+07  Rental unit in New York · ★4.89 · 2 bedrooms ·...
# 20740  5.119566e+07  Rental unit in New York · Studio · 1 bed · 1 bath
# 20741  2.523473e+07  Rental unit in New York · ★4.41 · 1 bedroom · ...
# 20742  3.339399e+06  Rental unit in New York · ★4.73 · 1 bedroom · ...
#
# ...

# %%
#deleting the duplicate values

df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum() #now we do not have duplicated rows in our data
# Out:
# 0

# %%
df.dtypes
# Out:
# id                                float64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                             float64
# minimum_nights                    float64
# number_of_reviews                 float64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count    float64
# availability_365                  float64
# number_of_reviews_ltm             float64
# license                            object
# rating                             object
# bedrooms                           object
# beds                                int64
# baths                              object
# dtype: object

# %%
#changing data types #type casting 
df['id'] = df['id'].astype(object)
df['host_id'] = df['host_id'].astype(object)

df.dtypes
# Out:
# id                                 object
# name                               object
# host_id                            object
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                             float64
# minimum_nights                    float64
# number_of_reviews                 float64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count    float64
# availability_365                  float64
# number_of_reviews_ltm             float64
# license                            object
# rating                             object
# bedrooms                           object
# beds                                int64
# baths                              object
# dtype: object

# %% [markdown]
# **EDA**
#
# **DATA ANALYSIS**

# %% [markdown]
# **univarite analysis**

# %%
#univarite analysis where we analysis each and single columns and there distribution

# %% [markdown]
# **PRICE DISTRIBUTION**

# %%
df['price']
# Out:
# 0         55.0
# 1        144.0
# 2        187.0
# 3        120.0
# 4         85.0
#          ...
# 20765     45.0
# 20766    105.0
# 20767    299.0
# 20768    115.0
# 20769    102.0
# Name: price, Length: 20724, dtype: float64

# %%
#creating a hist plot to check how our price is distributed across the data 

sns.histplot(data=df, x='price')
plt.show()

# %% [markdown]
# **CHECKING THE OUTLIERS**

# %%
sns.boxplot(data=df , x='price')
plt.show()

# %%
#after checking we have found that most of the price lies between 0 to somewhere 18000 in our data

# %%
#creating a new dataFrame

dataframe = df[df['price'] < 1800]

sns.boxplot(data=dataframe , x='price')
plt.show()

# %%
#here we can say price is eqaully distribuated

# %%
plt.figure(figsize=(8,5))
sns.histplot(data=dataframe, x='price',bins=100)
plt.title('Price Distribution')
plt.ylabel("Frequency")
plt.show()

# %%
#here we can say most of our price is between 0 to 500 apart from that there are very few property in our data

# %%
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'number_of_reviews_ltm', 'license', 'rating',
#        'bedrooms', 'beds', 'baths'],
#       dtype='object')

# %%
#Analysis reviewa per month

# %%
plt.figure(figsize=(8,5))
sns.histplot(data=dataframe, x='reviews_per_month',bins=100)
plt.ylabel("Frequency")
plt.show()

# %%
#so we have maximum review per month in our data between 0 to somewhere 7

# %% [markdown]
# **checking availability**

# %%
plt.figure(figsize=(8,5))
sns.histplot(data=dataframe, x='availability_365')
plt.title('Availability Distribution')
plt.ylabel("Frequency")
plt.show()

# %%
df.describe().columns  #numerical columns
# Out:
# Index(['latitude', 'longitude', 'price', 'minimum_nights', 'number_of_reviews',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'number_of_reviews_ltm', 'beds'],
#       dtype='object')

# %%
list(set(df.columns)-set(df.describe().columns))  #categorical columns
# Out:
# ['neighbourhood',
#  'host_name',
#  'last_review',
#  'neighbourhood_group',
#  'id',
#  'license',
#  'bedrooms',
#  'rating',
#  'room_type',
#  'baths',
#  'name',
#  'host_id']

# %%
numerical_columns = ['minimum_nights', 'number_of_reviews',
       'reviews_per_month', 'calculated_host_listings_count',
       'availability_365', 'number_of_reviews_ltm', 'beds']

# %%
categorical_columns = ['neighbourhood','host_name','last_review',
 'neighbourhood_group','id','license','bedrooms','rating','room_type','baths','name','host_id']

# %%
import matplotlib.pyplot as plt
import seaborn as sns
def uni_numerical_analysis(dataframe,columns):
    sns.set(style="darkgrid")
    plt.figure(figsize=(25,8))

    plt.subplot(1,3,1)
    sns.boxplot(data=dataframe,x=columns,orient="v").set(title="boxplot")
    plt.subplot(1,3,2)
    sns.histplot(dataframe[columns].dropna(),kde=True).set(title="histogram")

    plt.show()

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
for i in numerical_columns:
    uni_numerical_analysis(df,i)

# %%
def uni_categorical_analysis(dataframe,columns):
    sns.set(style="darkgrid")
    plt.figure(figsize=(16,10))

    sns.barplot(x=dataframe[columns].value_counts(),y=dataframe[columns].value_counts().index)
    for index,value in enumerate(dataframe[columns].value_counts()):
        plt.text(value,index,f" {value}",ha="left",va="center",color="black",fontsize=10)
        
    plt.show()

# %%
for i in categorical_columns:
    uni_categorical_analysis(df,i)

# %%
#finding average price of neighbourhood

# %%
avg_price =df.groupby('neighbourhood')['price'].mean()

# %%
avg_price
# Out:
# neighbourhood
# Allerton           100.828571
# Arden Heights      133.750000
# Arrochar           124.818182
# Arverne            203.059701
# Astoria            112.404432
#                       ...
# Windsor Terrace    160.824561
# Woodhaven           91.928571
# Woodlawn           133.500000
# Woodrow            143.500000
# Woodside            79.117647
# Name: price, Length: 221, dtype: float64

# %% [markdown]
# **Adding feature in our data**

# %%
df['price per bed'] = df['price']/df['beds']
df.head()
# Out:
#                      id                                               name  \
# 0             1312228.0         Rental unit in Brooklyn · ★5.0 · 1 bedroom
# 1            45277537.0  Rental unit in New York · ★4.67 · 2 bedrooms ·...
# 2  971000000000000000.0  Rental unit in New York · ★4.17 · 1 bedroom · ...
# 3             3857863.0  Rental unit in New York · ★4.64 · 1 bedroom · ...
# 4            40896611.0  Condo in New York · ★4.91 · Studio · 1 bed · 1...
#
#      host_id           host_name neighbourhood_group       neighbourhood  \
# 0    7130382              Walter            Brooklyn        Clinton Hill
# 1   51501835            Jeniffer           Manhattan      Hell's Kitchen
# 2  528871354              Joshua           Manhattan             Chelsea
# 3   19902271  John And Catherine           Manhattan  Washington Heights
# 4   61391963      Stay With Vibe           Manhattan         Murray Hill
#
#     latitude  longitude        room_type  price  ...  reviews_per_month  \
# ...

# %%
ppb = df.groupby('neighbourhood')['price per bed'].mean()

# %%
ppb
# Out:
# neighbourhood
# Allerton            69.584048
# Arden Heights       45.291667
# Arrochar           110.477273
# Arverne             78.572068
# Astoria             78.869664
#                       ...
# Windsor Terrace     94.429825
# Woodhaven           75.363095
# Woodlawn           102.000000
# Woodrow             62.041667
# Woodside            56.153263
# Name: price per bed, Length: 221, dtype: float64

# %% [markdown]
# **Bi variable analysis**

# %%
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'number_of_reviews_ltm', 'license', 'rating',
#        'bedrooms', 'beds', 'baths', 'price per bed'],
#       dtype='object')

# %%
#let see how price is depend on neighbourhood

sns.barplot(data = df , x='neighbourhood_group', y='price',hue='room_type')
# Out:
# <Axes: xlabel='neighbourhood_group', ylabel='price'>

# %%
#number of reviwes and price relationship 
plt.figure(figsize=(8,5))
plt.title('Reviews based on price')
sns.scatterplot(data=dataframe,x='number_of_reviews',y='price',hue='neighbourhood_group')
plt.show()

# %%
sns.pairplot(data=dataframe, vars=['price','minimum_nights','number_of_reviews','availability_365'],hue='room_type')

# %% [markdown]
# **Geographical Distribution**

# %%
plt.figure(figsize=(10,7))
sns.scatterplot(data=df,x='longitude',y='latitude',hue='room_type')
plt.title('Geographical Distribution of AirBNB')
plt.show()

# %% [markdown]
# **Relationship between all columns**

# %%
corr = df[['minimum_nights', 'number_of_reviews',
       'reviews_per_month', 'calculated_host_listings_count',
       'availability_365', 'number_of_reviews_ltm', 'beds']].corr()

# %%
corr  #value will be -1 to 1 always
# Out:
#                                 minimum_nights  number_of_reviews  \
# minimum_nights                        1.000000          -0.059001
# number_of_reviews                    -0.059001           1.000000
# reviews_per_month                    -0.122427           0.631592
# calculated_host_listings_count        0.015031          -0.114610
# availability_365                      0.034531          -0.050150
# number_of_reviews_ltm                -0.092388           0.605894
# beds                                 -0.026273           0.035777
#
#                                 reviews_per_month  \
# minimum_nights                          -0.122427
# number_of_reviews                        0.631592
# reviews_per_month                        1.000000
# calculated_host_listings_count          -0.108598
# availability_365                        -0.040662
# number_of_reviews_ltm                    0.849770
# beds                                     0.047898
#
# ...

# %%
plt.figure(figsize=(10,8))
sns.heatmap(data=corr,annot=True)
# Out:
# <Axes: >
